# %%
# IMPORT LIBARIES AND IMPORT DATASET

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("weather_datas.csv")
df.head()
# Out:
#          date  temperature_2m_min  temperature_2m_mean  temperature_2m_max  \
# 0  2023-07-01                25.6            27.262500                31.7
# 1  2023-07-02                25.2            26.712500                29.5
# 2  2023-07-03                24.9            27.233333                31.9
# 3  2023-07-04                24.5            28.079167                32.3
# 4  2023-07-05                25.1            27.129167                31.4
#
#    relative_humidity_2m_min  relative_humidity_2m_mean  \
# 0                        66                  85.416667
# 1                        75                  86.125000
# 2                        62                  85.083333
# 3                        57                  80.125000
# 4                        72                  86.625000
#
#    relative_humidity_2m_max  dew_point_2m_min  dew_point_2m_mean  \
# 0                        95              23.7          24.516667
# 1                        94              23.7          24.133333
# 2                        97              23.7          24.337500
# 3                        96              22.6          24.050000
# 4                        96              23.0          24.654167
#
#    dew_point_2m_max  ...  diffuse_radiation_max  direct_normal_irradiance_min  \
# 0              25.1  ...                  265.0                           0.0
# 1              24.8  ...                  380.0                           0.0
# 2              25.2  ...                  209.0                           0.0
# 3              25.6  ...                  261.0                           0.0
# 4              26.3  ...                  329.0                           0.0
#
#    direct_normal_irradiance_mean  direct_normal_irradiance_max  \
# 0                     126.779167                         675.0
# 1                      78.854167                         636.0
# 2                     237.658333                         710.8
# 3                     235.437500                         803.2
# 4                     205.233333                         707.5
#
#    terrestrial_radiation_instant_min  terrestrial_radiation_instant_mean  \
# 0                                0.0                          431.054167
# 1                                0.0                          431.095833
# 2                                0.0                          431.129167
# 3                                0.0                          431.170833
# 4                                0.0                          431.241667
#
#    terrestrial_radiation_instant_max  sunshine_duration_min  \
# 0                             1292.6                    0.0
# 1                             1292.9                    0.0
# 2                             1293.2                    0.0
# 3                             1293.6                    0.0
# 4                             1294.1                    0.0
#
#    sunshine_duration_mean  sunshine_duration_max
# 0              875.555000                 3600.0
# 1              681.860000                 3600.0
# 2             1500.000000                 3600.0
# 3             1445.632917                 3600.0
# 4             1426.476250                 3600.0
#
# [5 rows x 79 columns]

# %%
# PREPROCESSING

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (31, 79)
# ['date', 'temperature_2m_min', 'temperature_2m_mean', 'temperature_2m_max', 'relative_humidity_2m_min', 'relative_humidity_2m_mean', 'relative_humidity_2m_max', 'dew_point_2m_min', 'dew_point_2m_mean', 'dew_point_2m_max', 'apparent_temperature_min', 'apparent_temperature_mean', 'apparent_temperature_max', 'precipitation_min', 'precipitation_mean', 'precipitation_max', 'rain_min', 'rain_mean', 'rain_max', 'showers_min', 'showers_mean', 'showers_max', 'weather_code_min', 'weather_code_mean', 'weather_code_max', 'pressure_msl_min', 'pressure_msl_mean', 'pressure_msl_max', 'surface_pressure_min', 'surface_pressure_mean', 'surface_pressure_max', 'cloud_cover_min', 'cloud_cover_mean', 'cloud_cover_max', 'cloud_cover_low_min', 'cloud_cover_low_mean', 'cloud_cover_low_max', 'cloud_cover_mid_min', 'cloud_cover_mid_mean', 'cloud_cover_mid_max', 'cloud_cover_high_min', 'cloud_cover_high_mean', 'cloud_cover_high_max', 'et0_fao_evapotranspiration_min', 'et0_fao_evapotranspiration_mean', 'et0_fao_evapotranspiration_max', 'vapour_pressure_deficit_min', 'vapour_pressure_deficit_mean', 'vapour_pressure_deficit_max', 'wind_speed_10m_min', 'wind_speed_10m_mean', 'wind_speed_10m_max', 'wind_speed_100m_min', 'wind_speed_100m_mean', 'wind_speed_100m_max', 'wind_direction_10m_min', 'wind_direction_10m_mean', 'wind_direction_10m_max', 'wind_gusts_10m_min', 'wind_gusts_10m_mean', 'wind_gusts_10m_max', 'shortwave_radiation_min', 'shortwave_radiation_mean', 'shortwave_radiation_max', 'direct_radiation_min', 'direct_radiation_mean', 'direct_radiation_max', 'diffuse_radiation_min', 'diffuse_radiation_mean', 'diffuse_radiation_max', 'direct_normal_irradiance_min', 'direct_normal_irradiance_mean', 'direct_normal_irradiance_max', 'terrestrial_radiation_instant_min', 'terrestrial_radiation_instant_mean', 'terrestrial_radiation_instant_max', 'sunshine_duration_min', 'sunshine_duration_mean', 'sunshine_duration_max']

# %%
flood_related_cols = [
    'temperature_2m_mean','temperature_2m_min', 'temperature_2m_max', 'precipitation_mean', 'precipitation_min', 'precipitation_max', 'rain_mean', 'rain_min', 'rain_max', 'showers_mean', 'showers_min',
    'showers_max', 'relative_humidity_2m_min', 'relative_humidity_2m_max', 
    'relative_humidity_2m_mean', 'cloud_cover_mean', 'cloud_cover_min', 'cloud_cover_max'
]

# %%
df_numerical = df.select_dtypes(include=["number"])
corr_matrix = df_numerical.corr()

plt.figure(figsize=(18, 14))
sns.heatmap(corr_matrix, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.tight_layout()
plt.show()

# %%
df_numerical = df.select_dtypes(include=["number"])
corr_matrix = df_numerical.corr()

threshold_avg = 0.4
threshold_max = 0.6

selected_cols = set(flood_related_cols)
non_flood_cols = [col for col in df_numerical.columns if col not in flood_related_cols]

for col in non_flood_cols:
    if col in corr_matrix:
        corrs = [abs(corr_matrix[col][f]) for f in flood_related_cols if f in corr_matrix]
        if corrs:
            avg_corr = np.mean(corrs)
            max_corr = np.max(corrs)
            if avg_corr > threshold_avg or max_corr > threshold_max:
                selected_cols.add(col)

df_combined = df[sorted(selected_cols)]

# %%
print(selected_cols)
# Out:
# {'rain_mean', 'temperature_2m_max', 'temperature_2m_mean', 'rain_max', 'cloud_cover_max', 'precipitation_max', 'showers_min', 'cloud_cover_mean', 'precipitation_min', 'temperature_2m_min', 'showers_mean', 'relative_humidity_2m_max', 'cloud_cover_min', 'relative_humidity_2m_mean', 'precipitation_mean', 'relative_humidity_2m_min', 'rain_min', 'showers_max'}

# %%
plt.figure(figsize=(18, 14))
sns.heatmap(df_combined.corr(), annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Heatmap – Các biến phần A và các biến tương quan cao từ phần B", fontsize=16)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("weather_datas.csv")

# %%
from sklearn.feature_selection import mutual_info_regression

X = df_numerical.drop(columns=flood_related_cols)
results = {}

for target in flood_related_cols:
    y = df_numerical[target]
    mi_scores = mutual_info_regression(X, y, discrete_features='auto', random_state=0)
    results[target] = pd.Series(mi_scores, index=X.columns)

# Tính MI trung bình với các biến trong phần A
mi_df = pd.DataFrame(results)
mi_df["avg_mi"] = mi_df.mean(axis=1)
mi_df_sorted = mi_df.sort_values("avg_mi", ascending=False)

# Lọc các biến B có MI trung bình > 0.02 (tuỳ chỉnh ngưỡng)
selected_b = mi_df_sorted[mi_df_sorted["avg_mi"] > 0.02].index.tolist()
df_mi = df[flood_related_cols + selected_b]

# %%
plt.figure(figsize=(18, 10))
sns.barplot(data=mi_df_sorted.reset_index(), x="avg_mi", y="index")
plt.title("Mutual Information trung bình với các biến liên quan đến lũ")
plt.xlabel("Avg Mutual Information")
plt.ylabel("Biến phần B")
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("weather_datas.csv")

flood_related_cols = [
    'temperature_2m_mean','temperature_2m_min', 'temperature_2m_max', 'precipitation_mean', 'precipitation_min', 'precipitation_max', 'rain_mean', 'rain_min', 'rain_max', 'showers_mean', 'showers_min',
    'showers_max', 'relative_humidity_2m_min', 'relative_humidity_2m_max', 
    'relative_humidity_2m_mean', 'cloud_cover_mean', 'cloud_cover_min', 'cloud_cover_max'
]

df_numerical = df.select_dtypes(include=["number"])
print(len(df_numerical))
# Lọc lại phần A và B
A = [col for col in flood_related_cols if col in df_numerical.columns]
B = [col for col in df_numerical.columns if col not in A]

# Bước 3: Tính ma trận tương quan
corr_matrix = df_numerical.corr()

# Ma trận tương quan A ↔ A
corr_AA = corr_matrix.loc[A, A]

# Ma trận tương quan A ↔ B
corr_AB = corr_matrix.loc[A, B]

# In ra
print("🔷 Tương quan giữa các biến trong phần A:")
display(corr_AA)

print("\n🔶 Tương quan giữa các biến phần A với phần B:")
display(corr_AB)
# Out:
# 31
# 🔷 Tương quan giữa các biến trong phần A:
#                            temperature_2m_mean  temperature_2m_min  \
# temperature_2m_mean                   1.000000            0.224638
# temperature_2m_min                    0.224638            1.000000
# temperature_2m_max                    0.792526            0.028400
# precipitation_mean                   -0.509832            0.271091
# precipitation_min                          NaN                 NaN
# precipitation_max                    -0.497608            0.172995
# rain_mean                            -0.509832            0.271091
# rain_min                                   NaN                 NaN
# rain_max                             -0.497608            0.172995
# showers_mean                               NaN                 NaN
# showers_min                                NaN                 NaN
# showers_max                                NaN                 NaN
# relative_humidity_2m_min             -0.704888            0.138119
# relative_humidity_2m_max              0.165753           -0.383355
# relative_humidity_2m_mean            -0.885186           -0.136051
# cloud_cover_mean                     -0.256215            0.048519
# cloud_cover_min                      -0.064717            0.031640
# cloud_cover_max                      -0.383835           -0.081732
#
#                            temperature_2m_max  precipitation_mean  \
# temperature_2m_mean                  0.792526           -0.509832
# temperature_2m_min                   0.028400            0.271091
# temperature_2m_max                   1.000000           -0.400394
# precipitation_mean                  -0.400394            1.000000
# precipitation_min                         NaN                 NaN
# precipitation_max                   -0.460823            0.878806
# rain_mean                           -0.400394            1.000000
# rain_min                                  NaN                 NaN
# rain_max                            -0.460823            0.878806
# showers_mean                              NaN                 NaN
# showers_min                               NaN                 NaN
# showers_max                               NaN                 NaN
# relative_humidity_2m_min            -0.864652            0.636329
# relative_humidity_2m_max             0.385125           -0.113636
# relative_humidity_2m_mean           -0.704728            0.612291
# cloud_cover_mean                    -0.489013            0.170030
# cloud_cover_min                     -0.396818           -0.029703
# cloud_cover_max                     -0.329637            0.246642
#
#                            precipitation_min  precipitation_max  rain_mean  \
# temperature_2m_mean                      NaN          -0.497608  -0.509832
# temperature_2m_min                       NaN           0.172995   0.271091
# temperature_2m_max                       NaN          -0.460823  -0.400394
# precipitation_mean                       NaN           0.878806   1.000000
# precipitation_min                        NaN                NaN        NaN
# precipitation_max                        NaN           1.000000   0.878806
# rain_mean                                NaN           0.878806   1.000000
# rain_min                                 NaN                NaN        NaN
# rain_max                                 NaN           1.000000   0.878806
# showers_mean                             NaN                NaN        NaN
# showers_min                              NaN                NaN        NaN
# showers_max                              NaN                NaN        NaN
# relative_humidity_2m_min                 NaN           0.629505   0.636329
# relative_humidity_2m_max                 NaN          -0.030127  -0.113636
# relative_humidity_2m_mean                NaN           0.617246   0.612291
# cloud_cover_mean                         NaN           0.146641   0.170030
# cloud_cover_min                          NaN          -0.008469  -0.029703
# cloud_cover_max                          NaN           0.217540   0.246642
#
#                            rain_min  rain_max  showers_mean  showers_min  \
# temperature_2m_mean             NaN -0.497608           NaN          NaN
# temperature_2m_min              NaN  0.172995           NaN          NaN
# temperature_2m_max              NaN -0.460823           NaN          NaN
# precipitation_mean              NaN  0.878806           NaN          NaN
# precipitation_min               NaN       NaN           NaN          NaN
# precipitation_max               NaN  1.000000           NaN          NaN
# rain_mean                       NaN  0.878806           NaN          NaN
# rain_min                        NaN       NaN           NaN          NaN
# rain_max                        NaN  1.000000           NaN          NaN
# showers_mean                    NaN       NaN           NaN          NaN
# showers_min                     NaN       NaN           NaN          NaN
# showers_max                     NaN       NaN           NaN          NaN
# relative_humidity_2m_min        NaN  0.629505           NaN          NaN
# relative_humidity_2m_max        NaN -0.030127           NaN          NaN
# relative_humidity_2m_mean       NaN  0.617246           NaN          NaN
# cloud_cover_mean                NaN  0.146641           NaN          NaN
# cloud_cover_min                 NaN -0.008469           NaN          NaN
# cloud_cover_max                 NaN  0.217540           NaN          NaN
#
#                            showers_max  relative_humidity_2m_min  \
# temperature_2m_mean                NaN                 -0.704888
# temperature_2m_min                 NaN                  0.138119
# temperature_2m_max                 NaN                 -0.864652
# precipitation_mean                 NaN                  0.636329
# precipitation_min                  NaN                       NaN
# precipitation_max                  NaN                  0.629505
# rain_mean                          NaN                  0.636329
# rain_min                           NaN                       NaN
# rain_max                           NaN                  0.629505
# showers_mean                       NaN                       NaN
# showers_min                        NaN                       NaN
# showers_max                        NaN                       NaN
# relative_humidity_2m_min           NaN                  1.000000
# relative_humidity_2m_max           NaN                 -0.404196
# relative_humidity_2m_mean          NaN                  0.776807
# cloud_cover_mean                   NaN                  0.401183
# cloud_cover_min                    NaN                  0.253978
# cloud_cover_max                    NaN                  0.333010
#
#                            relative_humidity_2m_max  \
# temperature_2m_mean                        0.165753
# temperature_2m_min                        -0.383355
# temperature_2m_max                         0.385125
# precipitation_mean                        -0.113636
# precipitation_min                               NaN
# precipitation_max                         -0.030127
# rain_mean                                 -0.113636
# rain_min                                        NaN
# rain_max                                  -0.030127
# showers_mean                                    NaN
# showers_min                                     NaN
# showers_max                                     NaN
# relative_humidity_2m_min                  -0.404196
# relative_humidity_2m_max                   1.000000
# relative_humidity_2m_mean                  0.003914
# cloud_cover_mean                          -0.315395
# cloud_cover_min                           -0.347226
# cloud_cover_max                           -0.012652
#
#                            relative_humidity_2m_mean  cloud_cover_mean  \
# temperature_2m_mean                        -0.885186         -0.256215
# temperature_2m_min                         -0.136051          0.048519
# temperature_2m_max                         -0.704728         -0.489013
# precipitation_mean                          0.612291          0.170030
# precipitation_min                                NaN               NaN
# precipitation_max                           0.617246          0.146641
# rain_mean                                   0.612291          0.170030
# rain_min                                         NaN               NaN
# rain_max                                    0.617246          0.146641
# showers_mean                                     NaN               NaN
# showers_min                                      NaN               NaN
# showers_max                                      NaN               NaN
# relative_humidity_2m_min                    0.776807          0.401183
# relative_humidity_2m_max                    0.003914         -0.315395
# relative_humidity_2m_mean                   1.000000          0.189051
# cloud_cover_mean                            0.189051          1.000000
# cloud_cover_min                            -0.047215          0.857097
# cloud_cover_max                             0.365373          0.393500
#
#                            cloud_cover_min  cloud_cover_max
# temperature_2m_mean              -0.064717        -0.383835
# temperature_2m_min                0.031640        -0.081732
# temperature_2m_max               -0.396818        -0.329637
# precipitation_mean               -0.029703         0.246642
# precipitation_min                      NaN              NaN
# precipitation_max                -0.008469         0.217540
# rain_mean                        -0.029703         0.246642
# rain_min                               NaN              NaN
# rain_max                         -0.008469         0.217540
# showers_mean                           NaN              NaN
# showers_min                            NaN              NaN
# showers_max                            NaN              NaN
# relative_humidity_2m_min          0.253978         0.333010
# relative_humidity_2m_max         -0.347226        -0.012652
# relative_humidity_2m_mean        -0.047215         0.365373
# cloud_cover_mean                  0.857097         0.393500
# cloud_cover_min                   1.000000         0.130939
# cloud_cover_max                   0.130939         1.000000
# 🔶 Tương quan giữa các biến phần A với phần B:
#                            dew_point_2m_min  dew_point_2m_mean  \
# temperature_2m_mean               -0.171820           0.542665
# temperature_2m_min                 0.592923           0.321586
# temperature_2m_max                -0.300770           0.387318
# precipitation_mean                 0.158706           0.055172
# precipitation_min                       NaN                NaN
# precipitation_max                  0.224062           0.077553
# rain_mean                          0.158706           0.055172
# rain_min                                NaN                NaN
# rain_max                           0.224062           0.077553
# showers_mean                            NaN                NaN
# showers_min                             NaN                NaN
# showers_max                             NaN                NaN
# relative_humidity_2m_min           0.340237          -0.041507
# relative_humidity_2m_max          -0.159673           0.254745
# relative_humidity_2m_mean          0.329055          -0.096007
# cloud_cover_mean                   0.062437          -0.188123
# cloud_cover_min                    0.015693          -0.211714
# cloud_cover_max                   -0.117402          -0.139653
#
#                            dew_point_2m_max  apparent_temperature_min  \
# temperature_2m_mean                0.537220                  0.514095
# temperature_2m_min                 0.160534                  0.456218
# temperature_2m_max                 0.429739                  0.405890
# precipitation_mean                 0.042293                 -0.144213
# precipitation_min                       NaN                       NaN
# precipitation_max                  0.001202                 -0.091306
# rain_mean                          0.042293                 -0.144213
# rain_min                                NaN                       NaN
# rain_max                           0.001202                 -0.091306
# showers_mean                            NaN                       NaN
# showers_min                             NaN                       NaN
# showers_max                             NaN                       NaN
# relative_humidity_2m_min          -0.070823                 -0.369424
# relative_humidity_2m_max           0.087805                  0.461698
# relative_humidity_2m_mean         -0.236430                 -0.344130
# cloud_cover_mean                  -0.191588                 -0.213882
# cloud_cover_min                   -0.119675                 -0.100256
# cloud_cover_max                   -0.162220                 -0.348207
#
#                            apparent_temperature_mean  \
# temperature_2m_mean                         0.856745
# temperature_2m_min                         -0.036249
# temperature_2m_max                          0.777022
# precipitation_mean                         -0.405096
# precipitation_min                                NaN
# precipitation_max                          -0.355883
# rain_mean                                  -0.405096
# rain_min                                         NaN
# rain_max                                   -0.355883
# showers_mean                                     NaN
# showers_min                                      NaN
# showers_max                                      NaN
# relative_humidity_2m_min                   -0.669988
# relative_humidity_2m_max                    0.510151
# relative_humidity_2m_mean                  -0.665586
# cloud_cover_mean                           -0.404057
# cloud_cover_min                            -0.215016
# cloud_cover_max                            -0.369560
#
#                            apparent_temperature_max  weather_code_min  \
# temperature_2m_mean                        0.666063          0.079575
# temperature_2m_min                        -0.086358          0.190265
# temperature_2m_max                         0.837672         -0.235257
# precipitation_mean                        -0.178201          0.079343
# precipitation_min                               NaN               NaN
# precipitation_max                         -0.211940         -0.000538
# rain_mean                                 -0.178201          0.079343
# rain_min                                        NaN               NaN
# rain_max                                  -0.211940         -0.000538
# showers_mean                                    NaN               NaN
# showers_min                                     NaN               NaN
# showers_max                                     NaN               NaN
# relative_humidity_2m_min                  -0.629468          0.228718
# relative_humidity_2m_max                   0.509454         -0.112560
# relative_humidity_2m_mean                 -0.503014         -0.025076
# cloud_cover_mean                          -0.553973          0.768017
# cloud_cover_min                           -0.421633          0.783125
# cloud_cover_max                           -0.307359          0.137462
#
#                            weather_code_mean  weather_code_max  \
# temperature_2m_mean                -0.708201         -0.512442
# temperature_2m_min                  0.223404          0.385975
# temperature_2m_max                 -0.672418         -0.455738
# precipitation_mean                  0.752072          0.677338
# precipitation_min                        NaN               NaN
# precipitation_max                   0.626854          0.743767
# rain_mean                           0.752072          0.677338
# rain_min                                 NaN               NaN
# rain_max                            0.626854          0.743767
# showers_mean                             NaN               NaN
# showers_min                              NaN               NaN
# showers_max                              NaN               NaN
# relative_humidity_2m_min            0.813642          0.591027
# relative_humidity_2m_max           -0.277182         -0.113031
# relative_humidity_2m_mean           0.776791          0.630840
# cloud_cover_mean                    0.283727         -0.089411
# cloud_cover_min                     0.089098         -0.235290
# cloud_cover_max                     0.265662          0.093124
#
#                            pressure_msl_min  ...  diffuse_radiation_max  \
# temperature_2m_mean                0.119526  ...              -0.547798
# temperature_2m_min                -0.286987  ...               0.105221
# temperature_2m_max                 0.246854  ...              -0.735988
# precipitation_mean                -0.225400  ...               0.186714
# precipitation_min                       NaN  ...                    NaN
# precipitation_max                 -0.167639  ...               0.280695
# rain_mean                         -0.225400  ...               0.186714
# rain_min                                NaN  ...                    NaN
# rain_max                          -0.167639  ...               0.280695
# showers_mean                            NaN  ...                    NaN
# showers_min                             NaN  ...                    NaN
# showers_max                             NaN  ...                    NaN
# relative_humidity_2m_min          -0.368942  ...               0.640285
# relative_humidity_2m_max           0.574865  ...              -0.384364
# relative_humidity_2m_mean         -0.061712  ...               0.494821
# cloud_cover_mean                  -0.305408  ...               0.433876
# cloud_cover_min                   -0.297220  ...               0.268884
# cloud_cover_max                   -0.066214  ...               0.418224
#
#                            direct_normal_irradiance_min  \
# temperature_2m_mean                                 NaN
# temperature_2m_min                                  NaN
# temperature_2m_max                                  NaN
# precipitation_mean                                  NaN
# precipitation_min                                   NaN
# precipitation_max                                   NaN
# rain_mean                                           NaN
# rain_min                                            NaN
# rain_max                                            NaN
# showers_mean                                        NaN
# showers_min                                         NaN
# showers_max                                         NaN
# relative_humidity_2m_min                            NaN
# relative_humidity_2m_max                            NaN
# relative_humidity_2m_mean                           NaN
# cloud_cover_mean                                    NaN
# cloud_cover_min                                     NaN
# cloud_cover_max                                     NaN
#
#                            direct_normal_irradiance_mean  \
# temperature_2m_mean                             0.755989
# temperature_2m_min                             -0.074076
# temperature_2m_max                              0.904693
# precipitation_mean                             -0.411898
# precipitation_min                                    NaN
# precipitation_max                              -0.463375
# rain_mean                                      -0.411898
# rain_min                                             NaN
# rain_max                                       -0.463375
# showers_mean                                         NaN
# showers_min                                          NaN
# showers_max                                          NaN
# relative_humidity_2m_min                       -0.816962
# relative_humidity_2m_max                        0.506421
# relative_humidity_2m_mean                      -0.680096
# cloud_cover_mean                               -0.575585
# cloud_cover_min                                -0.408757
# cloud_cover_max                                -0.397519
#
#                            direct_normal_irradiance_max  \
# temperature_2m_mean                            0.630289
# temperature_2m_min                             0.077564
# temperature_2m_max                             0.816708
# precipitation_mean                            -0.218611
# precipitation_min                                   NaN
# precipitation_max                             -0.281116
# rain_mean                                     -0.218611
# rain_min                                            NaN
# rain_max                                      -0.281116
# showers_mean                                        NaN
# showers_min                                         NaN
# showers_max                                         NaN
# relative_humidity_2m_min                      -0.651559
# relative_humidity_2m_max                       0.441045
# relative_humidity_2m_mean                     -0.500922
# cloud_cover_mean                              -0.464783
# cloud_cover_min                               -0.410248
# cloud_cover_max                               -0.204006
#
#                            terrestrial_radiation_instant_min  \
# temperature_2m_mean                                      NaN
# temperature_2m_min                                       NaN
# temperature_2m_max                                       NaN
# precipitation_mean                                       NaN
# precipitation_min                                        NaN
# precipitation_max                                        NaN
# rain_mean                                                NaN
# rain_min                                                 NaN
# rain_max                                                 NaN
# showers_mean                                             NaN
# showers_min                                              NaN
# showers_max                                              NaN
# relative_humidity_2m_min                                 NaN
# relative_humidity_2m_max                                 NaN
# relative_humidity_2m_mean                                NaN
# cloud_cover_mean                                         NaN
# cloud_cover_min                                          NaN
# cloud_cover_max                                          NaN
#
#                            terrestrial_radiation_instant_mean  \
# temperature_2m_mean                                 -0.474615
# temperature_2m_min                                  -0.072632
# temperature_2m_max                                  -0.444730
# precipitation_mean                                   0.092716
# precipitation_min                                         NaN
# precipitation_max                                    0.071056
# rain_mean                                            0.092716
# rain_min                                                  NaN
# rain_max                                             0.071056
# showers_mean                                              NaN
# showers_min                                               NaN
# showers_max                                               NaN
# relative_humidity_2m_min                             0.436423
# relative_humidity_2m_max                            -0.247795
# relative_humidity_2m_mean                            0.546562
# cloud_cover_mean                                     0.161727
# cloud_cover_min                                      0.054202
# cloud_cover_max                                      0.125757
#
#                            terrestrial_radiation_instant_max  \
# temperature_2m_mean                                -0.460054
# temperature_2m_min                                 -0.069799
# temperature_2m_max                                 -0.433872
# precipitation_mean                                  0.084494
# precipitation_min                                        NaN
# precipitation_max                                   0.062379
# rain_mean                                           0.084494
# rain_min                                                 NaN
# rain_max                                            0.062379
# showers_mean                                             NaN
# showers_min                                              NaN
# showers_max                                              NaN
# relative_humidity_2m_min                            0.426905
# relative_humidity_2m_max                           -0.246977
# relative_humidity_2m_mean                           0.534514
# cloud_cover_mean                                    0.155325
# cloud_cover_min                                     0.048529
# cloud_cover_max                                     0.123658
#
#                            sunshine_duration_min  sunshine_duration_mean  \
# temperature_2m_mean                          NaN                0.670937
# temperature_2m_min                           NaN               -0.034032
# temperature_2m_max                           NaN                0.788800
# precipitation_mean                           NaN               -0.397517
# precipitation_min                            NaN                     NaN
# precipitation_max                            NaN               -0.461291
# rain_mean                                    NaN               -0.397517
# rain_min                                     NaN                     NaN
# rain_max                                     NaN               -0.461291
# showers_mean                                 NaN                     NaN
# showers_min                                  NaN                     NaN
# showers_max                                  NaN                     NaN
# relative_humidity_2m_min                     NaN               -0.689247
# relative_humidity_2m_max                     NaN                0.460882
# relative_humidity_2m_mean                    NaN               -0.574890
# cloud_cover_mean                             NaN               -0.561082
# cloud_cover_min                              NaN               -0.448293
# cloud_cover_max                              NaN               -0.302403
#
#                            sunshine_duration_max
# temperature_2m_mean                     0.308686
# temperature_2m_min                      0.136690
# temperature_2m_max                      0.354076
# precipitation_mean                     -0.151444
# precipitation_min                            NaN
# precipitation_max                      -0.075963
# rain_mean                              -0.151444
# rain_min                                     NaN
# rain_max                               -0.075963
# showers_mean                                 NaN
# showers_min                                  NaN
# showers_max                                  NaN
# relative_humidity_2m_min               -0.295653
# relative_humidity_2m_max               -0.012652
# relative_humidity_2m_mean              -0.243810
# cloud_cover_mean                       -0.158928
# cloud_cover_min                        -0.235621
# cloud_cover_max                        -0.033333
#
# [18 rows x 60 columns]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_AA, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Tuong quan trong phan A")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(corr_AB, fmt=".2f", cmap="coolwarm", square=True)
plt.title("Tuong quan trong phan B")
plt.tight_layout()
plt.show()
